# %% [markdown]
# ## Cabeçalho

# %% [markdown]
# Para editar metadados, recomendo criar uma pasta `Base` com as pastas `mais` e `website` representantes dos respectivos repositórios da Base dos Dados. E então editar metadados em sua instância local do CKAN, que pode ser criada através das instruções contidas em [github.com/basedosdados/website](https://github.com/basedosdados/website). Após verificar que as alterações são válidas, peça a chave da API do CKAN e realize a migração. Todos estes passos usam três endpoints do CKAN: `package_show`, `bd_dataset_validate` e `package_update`.
#
# - `package_show` é um endpoint GET que retorna os dados de uma dataset com seus respectivos resources, groups e tags;
# - `bd_dataset_validate` é um endpoint POST que valida se os dados de dataset são válidos/satisfatórios;
# - `package_update` é um endpoint POST que atualiza um dataset caso a modificação seja válida.
#
# Na prática extraia dados de `package_show`, altere-os, valide com `bd_dataset_validate` e atualize com `package_update`.
#
# \* A classe `RemoteCKAN` permite acessar os endpoints do CKAN "diretamente".
# \* As vezes é necessário realizar download de todos os datasets do CKAN Prod pro ambiente Local.

# %%
from pathlib import Path

import json
import yaml
from ckanapi import RemoteCKAN
from IPython.display import clear_output

# %%
import basedosdados as bd
# Out:
# /Users/m/miniconda3/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ## Definindo os Ambientes

# %%
# ADICIONE CHAVES DE API DO CKAN SE NECESSÁRIO
# AS CHAVES PODEM SER ADICIONADAS (SÃO OPCIONAIS)
# EM <CKAN_API_TOKEN>, OMITA A VARIÁVEL CASO QUEIRA.

ckan_local = RemoteCKAN("http://localhost:5000/", "<CKAN_API_TOKEN>")
ckan_prod  = RemoteCKAN("https://basedosdados.org/", "<CKAN_API_TOKEN>")
ckan_stage = RemoteCKAN("https://staging.basedosdados.org/", "")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/71/tpcbz38n2xs1q_96jb1sdmrw0000gn/T/ipykernel_59868/3383559367.py in <module>
#       3 # EM <CKAN_API_TOKEN>, OMITA A VARIÁVEL CASO QUEIRA.
#       4
# ----> 5 ckan_local = RemoteCKAN("http://localhost:5000/", "<CKAN_API_TOKEN>")
#       6 ckan_prod  = RemoteCKAN("https://basedosdados.org/", "<CKAN_API_TOKEN>")
#       7 ckan_stage = RemoteCKAN("https://staging.basedosdados.org/", "")
#
# NameError: name 'RemoteCKAN' is not defined

# %% [markdown]
# ## Visualizando um Dataset

# %%
# md.create()
md = bd.Metadata(dataset_id='teste_teste', table_id='teste_teste')
md.create(if_exists='replace',table_only=False)
md.publish(if_exists='replace',all=True)
# Out:
# ---------------------------------------------------------------------------
# BaseDosDadosException                     Traceback (most recent call last)
# ~/gabinite_sv/bd+/mais/python-package/basedosdados/upload/metadata.py in publish(self, all, if_exists, update_locally)
#     412         try:
# --> 413             self.validate()
#     414
#
# ~/gabinite_sv/bd+/mais/python-package/basedosdados/upload/metadata.py in validate(self)
#     353             message = f"{self.filepath} has validation errors: {error}"
# --> 354             raise BaseDosDadosException(message)
#     355
#
# BaseDosDadosException: /Users/m/gabinite_sv/bd+/mais/bases/aopsdkpokasdppoaskd/dataset_config.yaml has validation errors: {'aopsdkpokasdppoaskd': [{'loc': ['resources', 0, 'ExternalLink', 'url'], 'msg': 'field required', 'type': 'value_error.missing'}, {'loc': ['resources', 0, 'ExternalLink', 'dataset_id'], 'msg': 'field required', 'type': 'value_error.missing'}]}
#
# During handling of the above exception, another exception occurred:
#
# BaseDosDadosException                     Traceback (most recent call last)
# ~/gabinite_sv/bd+/mais/python-package/basedosdados/upload/metadata.py in publish(self, all, if_exists, update_locally)
#     427                 if all:
# --> 428                     self.dataset_metadata_obj.publish(if_exists=if_exists)
#     429
#
# ~/gabinite_sv/bd+/mais/python-package/basedosdados/upload/metadata.py in publish(self, all, if_exists, update_locally)
#     460             )
# --> 461             raise BaseDosDadosException(message)
#     462
#
# BaseDosDadosException: Could not publish metadata due to a validation error. Please see the traceback below to get information on how to correct it.
#
# BaseDosDadosException("/Users/m/gabinite_sv/bd+/mais/bases/aopsdkpokasdppoaskd/dataset_config.yaml has validation errors: {'aopsdkpokasdppoaskd': [{'loc': ['resources', 0, 'ExternalLink', 'url'], 'msg': 'field required', 'type': 'value_error.missing'}, {'loc': ['resources', 0, 'ExternalLink', 'dataset_id'], 'msg': 'field required', 'type': 'value_error.missing'}]}")
#
# During handling of the above exception, another exception occurred:
#
# BaseDosDadosException                     Traceback (most recent call last)
# /var/folders/71/tpcbz38n2xs1q_96jb1sdmrw0000gn/T/ipykernel_59868/636235756.py in <module>
#       1 # md.create()
#       2
# ----> 3 md.publish(if_exists='replace',all=True)
#
# ~/gabinite_sv/bd+/mais/python-package/basedosdados/upload/metadata.py in publish(self, all, if_exists, update_locally)
#     459                 f"ect it.\n\n{repr(e)}"
#     460             )
# --> 461             raise BaseDosDadosException(message)
#     462
#     463         except NotAuthorized as e:
#
# BaseDosDadosException: Could not publish metadata due to a validation error. Please see the traceback below to get information on how to correct it.
#
# BaseDosDadosException('Could not publish metadata due to a validation error. Please see the traceback below to get information on how to correct it.\n\nBaseDosDadosException("/Users/m/gabinite_sv/bd+/mais/bases/aopsdkpokasdppoaskd/dataset_config.yaml has validation errors: {\'aopsdkpokasdppoaskd\': [{\'loc\': [\'resources\', 0, \'ExternalLink\', \'url\'], \'msg\': \'field required\', \'type\': \'value_error.missing\'}, {\'loc\': [\'resources\', 0, \'ExternalLink\', \'dataset_id\'], \'msg\': \'field required\', \'type\': \'value_error.missing\'}]}")')

# %%
package_list = ckan_local.action.package_list()
# package_name = package_list[0]

# %%
package = ckan_stage.action.package_show(name_or_id='br-senado-cpipandemia')

# %%
package['resources'][0]['uncompressed_file_size'] = 18900
package['resources'][0]['compressed_file_size']=4000

# %% [markdown]
# ## Alterando um Dataset

# %% [markdown]
# Altere algum valor de package para alterar os metadados. E então adicione como abaixo:
# Caso queira alterar a validação, cheque `./ckanext-basedosdados/ckanext/basedosdados/validator`.

# %%
ckan_stage.action.package_update(**package)
# Out:
# {'id': 'ab694d40-c598-4860-a185-9ab134b78b3d',
#  'name': 'br-senado-cpipandemia',
#  'title': 'Discursos da CPI da Pandemia',
#  'type': 'dataset',
#  'notes': 'Base de dados contendo informações sobre a Comissão Parlamentar de Inquérito (CPI) da Pandemia da COVID-19 no Brasil, instalada no Senado Federal em abril de 2021.Constam no momento os discursos proferidos em suas sessões e que foram transcritos pelo Senado oficialmente.',
#  'author': 'Serviço de Dados Abertos do Senado Federal',
#  'author_email': None,
#  'maintainer': '',
#  'maintainer_email': '',
#  'state': 'active',
#  'license_id': '',
#  'url': None,
#  'version': '',
#  'metadata_created': '2022-01-30T15:19:29.501160',
#  'metadata_modified': '2022-02-09T17:26:08.445604',
#  'creator_user_id': '27eaffe3-f79b-469f-8f02-4716146bdfcc',
#  'private': False,
#  'license_title': '',
#  'num_resources': 4,
#  'resources': [{'id': 'd0a9ca9b-4fd6-4cae-ad7d-a9323db55103',
#    'name': 'discursos',
#    'description': 'Tabela contendo todos os discursos proferidos na Comissão Parlamentar deInquérito da Pandemia da COVID-19 no Brasil, instalada no Senado Federal em27/04/2021.Constam da base todas as falas registradas e transcritas pela equipe do Senado,bem como informações sobre duração das falas e informações sobre a pessoa discursante.',
#    'position': 0,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2021-07-25T12:46:08.549297',
#    'format': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2022-02-09T17:26:08.453232',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'ab694d40-c598-4860-a185-9ab134b78b3d',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'bdm_table',
#    'dataset_id': 'br_senado_cpipandemia',
#    'table_id': 'discursos',
#    'spatial_coverage': [{'continent': 'south_america', 'country': 'br'}],
#    'temporal_coverage': ['2021'],
#    'update_frequency': 'day',
#    'observation_level': [{'columns': ['sequencial_sessao']},
#     {'columns': ['nome_discursante']},
#     {'columns': ['horario_inicio_discurso']}],
#    'version': '1.0',
#    'published_by': {'name': 'Rodrigo Dornelles',
#     'email': 'rodornelles@gmail.com',
#     'github_user': '',
#     'ckan_user': '',
#     'website': None},
#    'data_cleaned_by': {'name': 'Rodrigo Dornelles',
#     'email': 'rodornelles@gmail.com',
#     'github_user': '',
#     'ckan_user': '',
#     'website': 'https://github.com/basedosdados/mais/tree/master/bases/br_senado_cpipandemia/output'},
#    'data_cleaning_description': '- Foram extraídas as sessões da CPI da Pandemia via API do Senado Federal\n- Para cada sessão, foram raspadas as respectivas notas taquigráficas\n- Foi montado uma base de dados preliminar reunindo todos os discursos proferidos,\nbem como seu horário de início e final.\n- Também havia os dados de partido político, UF do partido e bloco parlamentar a\nque pertencia a pessoa que discusrsava, caso fosse parlamentar.\n- Esses dados foram limpos de forma a gerar uma tabela tidy. Foram acrescentadas\ninformações como gênero (usando o pacote genderBR) e extraídas informações como\nAlém de informações como se falava fora do microfone, por videoconferência,\nno exercício da presidência, etc.\n',
#    'data_cleaning_code_url': 'https://github.com/basedosdados/mais/tree/master/bases/br_senado_cpipandemia/code',
#    'partner_organization': {'name': '', 'organization_id': ''},
#    'auxiliary_files_url': '',
#    'source_bucket_name': 'rfdornelles',
#    'project_id_prod': 'rfdornelles-bq',
#    'project_id_staging': 'rfdornelles-bq',
#    'partitions': [],
#    'uncompressed_file_size': 18900,
#    'compressed_file_size': 4000,
#    'columns': [{'name': 'sequencial_sessao',
#      'description': 'Número sequencial da sessão realizada pela CPI da Pandemia.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'data_sessao',
#      'description': 'Data da sessão',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'texto_discurso',
#      'description': 'Inteiro teor do discurso ou fala proferidos por alguém, seja Senador/a, depoente, etc.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'nome_discursante',
#      'description': 'Nome da pessoa que proferiu o discurso ou fala',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'genero_discursante',
#      'description': 'Gênero da pessoa que proferiu  o discurso ou fala',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'categoria_discursante',
#      'description': 'Categoria em que a pessoa que falou se enquadra no momento da fala',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'horario_inicio_discurso',
#      'description': 'Data e horário em que a fala foi iniciada.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'horario_fim_discurso',
#      'description': 'Data e horário em que a fala foi finalizada ou interrompida.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'duracao_discurso',
#      'description': 'A duração em segundos da fala.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'sigla_partido',
#      'description': 'Sigla do partido da pessoa que falou (caso seja Senador/a)',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'sigla_uf_partido',
#      'description': 'Sigla da UF do partido da pessoa que falou (caso seja Senador/a)',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'bloco_parlamentar',
#      'description': 'Bloco parlamentar a que a pessoa que falou pertence (caso seja Senador/a).',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'sinalizacao_pela_ordem',
#      'description': 'Se a fala foi feita com sinalização de que a pessoa estava falando objetivo de solicitar informações sobre o andamento dos trabalhos da sessão, fazer reclamação quanto à observância do regimento e apontar falha ou equívoco em relação à proposição da pauta.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'sinalizacao_questao_ordem',
#      'description': 'Se a fala foi feita com sinalização de foi realizada enquanto Senador/a formulava questão de ordem à Presidência da Sessão.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'sinalizacao_fora_microfone',
#      'description': 'Se a fala foi feita com sinalização que que foi realizada fora do microfone.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'sinalizacao_responder_questao_ordem',
#      'description': 'Se a fala foi feita com sinalização de que se tratava de resposta à questão de ordem.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'sinalizacao_por_videoconferencia',
#      'description': 'Se a fala foi sinalizada como realziada por videoconferência.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'sinalizacao_para_interpelar',
#      'description': 'Se a fala foi feita com sinalização de que fora feita para interpelar.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'sinalizacao_para_expor',
#      'description': 'Se a fala foi feita com sinalização de que fora feita para realizar uma exposição.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'sinalizacao_para_depor',
#      'description': 'Se a fala foi feita com sinalização de que foi feita para depor.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False},
#     {'name': 'sinalizacao_como_presidente',
#      'description': 'Se a fala foi feita com sinalização de que a pessoa que falava estava no exercício da presidência da sessão.',
#      'temporal_coverage': [],
#      'covered_by_dictionary': 'no',
#      'has_sensitive_data': 'no',
#      'is_in_staging': True,
#      'is_partition': False}]},
#   {'id': 'e0f078a9-5d40-40c6-8b30-f87fb3369f0a',
#    'name': 'Baixar Original',
#    'description': '',
#    'position': 1,
#    'url': 'https://legis.senado.leg.br/comissoes/comissao?codcol=2441',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2021-07-25T12:47:15.548201',
#    'format': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2022-01-30T15:19:29.445088',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'ab694d40-c598-4860-a185-9ab134b78b3d',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'external_link',
#    'dataset_id': 'br_senado_cpipandemia',
#    'language': ['portuguese'],
#    'has_api': 'yes',
#    'is_free': 'yes',
#    'requires_registration': 'no',
#    'availability': 'online',
#    'country_ip_address_required': None,
#    'license': 'mit',
#    'spatial_coverage': None,
#    'temporal_coverage': [],
#    'observation_level': []},
#   {'id': '23f9afa2-c1e8-4f4d-8bc9-af9aef6c2aa8',
#    'name': 'Visualizar',
#    'description': None,
#    'position': 2,
#    'url': 'https://rfdornelles.shinyapps.io/cpipandemia/',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2021-08-16T23:39:45.199938',
#    'format': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2022-01-30T15:19:29.445330',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'ab694d40-c598-4860-a185-9ab134b78b3d',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'external_link',
#    'dataset_id': 'br_senado_cpipandemia',
#    'language': ['portuguese'],
#    'has_api': 'yes',
#    'is_free': 'yes',
#    'requires_registration': 'no',
#    'availability': 'online',
#    'country_ip_address_required': None,
#    'license': 'mit',
#    'spatial_coverage': None,
#    'temporal_coverage': [],
#    'observation_level': []},
#   {'id': 'ed11fa56-6fdc-4908-80f8-32fa40a0917f',
#    'name': 'Teste',
#    'description': 'Esse é um teste.',
#    'position': 3,
#    'url': '',
#    'cache_last_updated': None,
#    'cache_url': None,
#    'created': '2022-02-08T23:31:52.391177',
#    'format': '',
#    'hash': '',
#    'last_modified': None,
#    'metadata_modified': '2022-02-08T23:31:52.348271',
#    'mimetype': None,
#    'mimetype_inner': None,
#    'package_id': 'ab694d40-c598-4860-a185-9ab134b78b3d',
#    'size': None,
#    'state': 'active',
#    'url_type': None,
#    'resource_type': 'information_request',
#    'dataset_id': 'br_senado_cpipandemia',
#    'number': '123143153',
#    'requested_by': {'name': 'Ricardo'},
#    'spatial_coverage': [{'continent': 'south_america', 'country': 'br'}],
#    'data_url': 'www.ars'}],
#  'groups': [{'id': 'f3a8df10-09a2-4557-b59b-e2d402117ddd',
#    'name': 'historia',
#    'title': 'História',
#    'type': 'group',
#    'description': '',
#    'image_url': '2020-06-25-031557.126389Colosseum-Rome.jpg',
#    'created': '2020-06-25T03:15:57.332926',
#    'is_organization': False,
#    'approval_status': 'approved',
#    'state': 'active',
#    'capacity': 'public',
#    'display_name': 'História',
#    'image_display_url': 'https://basedosdados.org/uploads/group/2020-06-25-031557.126389Colosseum-Rome.jpg'},
#   {'id': 'e5d6e7cd-f1b0-4160-bbba-86cc55b818d5',
#    'name': 'politica',
#    'title': 'Política',
#    'type': 'group',
#    'description': '',
#    'image_url': '2019-09-19-060252.188862politica.jpg',
#    'created': '2019-09-17T04:57:32.417077',
#    'is_organization': False,
#    'approval_status': 'approved',
#    'state': 'active',
#    'capacity': 'public',
#    'display_name': 'Política',
#    'image_display_url': 'https://basedosdados.org/uploads/group/2019-09-19-060252.188862politica.jpg'}],
#  'owner_org': '6860f1ee-c704-499b-a43b-3ec67a22e385',
#  'organization': {'id': '6860f1ee-c704-499b-a43b-3ec67a22e385',
#   'name': 'senado-federal',
#   'title': 'Senado Federal',
#   'type': 'organization',
#   'description': 'senado.leg.br',
#   'image_url': '2019-11-03-020700.776164SenadoFederaldoBrasilFlag.jpg',
#   'created': '2019-11-03T02:07:00.788286',
#   'is_organization': True,
#   'approval_status': 'approved',
#   'state': 'active'},
#  'num_tags': 31,
#  'tags': [{'id': '188affa8-ce42-483e-92e0-d38d645b4830',
#    'name': 'COVID-19',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'COVID-19'},
#   {'id': '419e4c44-32cb-41a0-90f2-42ea56283760',
#    'name': 'COVID19',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'COVID19'},
#   {'id': 'b3aa1ef3-12a4-471b-a823-aafcf83dceac',
#    'name': 'CPI',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'CPI'},
#   {'id': 'bab85db3-4509-43a2-915e-09b17a1630d2',
#    'name': 'analise de texto',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'analise de texto'},
#   {'id': '64d0c881-f7d0-4bd0-975d-43463a4f1e06',
#    'name': 'arquivo',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'arquivo'},
#   {'id': '79b31bbe-f7a9-4782-bb7a-b67e6aa30514',
#    'name': 'cidadania',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'cidadania'},
#   {'id': '8c8a3100-c02e-43fc-89c8-216af9883619',
#    'name': 'congresso',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'congresso'},
#   {'id': 'dc403b28-cebd-4484-addb-e376f72ac58b',
#    'name': 'coronavirus',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'coronavirus'},
#   {'id': '74ff7feb-51ee-42fa-87d4-848693c236fd',
#    'name': 'dados Abertos',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'dados Abertos'},
#   {'id': '65077330-b7f9-416a-a99b-00c5aca61f94',
#    'name': 'discurso',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'discurso'},
#   {'id': '5fdaf380-ba68-430f-92b6-703723156fe0',
#    'name': 'genocidio',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'genocidio'},
#   {'id': 'bf57649a-e3a0-4607-9350-a8e084eede16',
#    'name': 'governo',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'governo'},
#   {'id': 'a425104e-c11e-4c1e-b666-fbf57f6e06d8',
#    'name': 'instituicoes',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'instituicoes'},
#   {'id': '51c62587-61ae-4b63-baf8-3d388b5fe14c',
#    'name': 'legislativo',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'legislativo'},
#   {'id': '90a5d734-39c5-423e-afc3-91e5a55c75cd',
#    'name': 'legislatura',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'legislatura'},
#   {'id': '0a716590-9eef-41f6-a0ab-a9cf55b6d2cb',
#    'name': 'lei',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'lei'},
#   {'id': '73c9f622-bc9c-4361-a93e-bed8c908931f',
#    'name': 'linguistica',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'linguistica'},
#   {'id': 'c7297315-30c1-4282-8529-3e273c744111',
#    'name': 'ministerio',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'ministerio'},
#   {'id': 'df030c7f-39e4-4099-8d75-f2c7ffd36974',
#    'name': 'mortalidade',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'mortalidade'},
#   {'id': '1a065bbf-c899-4f13-b319-13c10f3741af',
#    'name': 'pandemia',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'pandemia'},
#   {'id': '03304a31-5f8b-4b57-a069-771fd0b110fa',
#    'name': 'parlamento',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'parlamento'},
#   {'id': '45211e84-94f1-4bb6-b275-edcdfbb5e278',
#    'name': 'partido',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'partido'},
#   {'id': '3f4c08de-7a11-4490-8bb5-80a49d0e6444',
#    'name': 'politica publica',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'politica publica'},
#   {'id': '40ec2668-e4d2-444e-ae86-a629ec9f429e',
#    'name': 'presidencia',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'presidencia'},
#   {'id': '4a3c65d8-3c09-4291-b9e0-75c991156621',
#    'name': 'proposicao',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'proposicao'},
#   {'id': '2d7b8c15-6d8e-4faa-8245-6489f9abc43e',
#    'name': 'prova',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'prova'},
#   {'id': '279ec39b-41a9-4eb3-b67c-711ba8aea23b',
#    'name': 'relacoes de genero',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'relacoes de genero'},
#   {'id': 'afbe2799-3d8b-4e7e-89f4-07e16d9c7c1c',
#    'name': 'sentenca',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'sentenca'},
#   {'id': '3dc03a06-5844-4e9b-83f3-4a35d63a6221',
#    'name': 'testemunho',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'testemunho'},
#   {'id': '90d7561c-e6cc-4518-b415-76d92884ce0c',
#    'name': 'transparencia',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'transparencia'},
#   {'id': '1f3d1081-6bc4-462f-ba4b-db3cb0eb8803',
#    'name': 'virus',
#    'vocabulary_id': None,
#    'state': 'active',
#    'display_name': 'virus'}],
#  'relationships_as_object': [],
#  'relationships_as_subject': [],
#  'isopen': False,
#  'extras': [{'key': 'dataset_args', 'value': {}}]}
